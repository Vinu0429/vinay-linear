# %% [markdown]
# # LOAD LAIBRARIES

# %% [markdown]
# ## simple linear regression with single varibale value

# %%
# STEP 1 ) LOAD DATA 
import pandas as pd 
import numpy as np  
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from sklearn import linear_model

# %%
df = pd.read_csv(r"C:\Users\samud\Downloads\insurance.csv")
df
# Out:
#     age  braught_insurance
# 0    22                  0
# 1    25                  0
# 2    47                  1
# 3    52                  0
# 4    46                  1
# 5    56                  1
# 6    55                  0
# 7    60                  1
# 8    62                  1
# 9    61                  1
# 10   18                  0
# 11   28                  0
# 12   27                  0
# 13   29                  0
# 14   49                  1
# 15   55                  1
# 16   25                  1
# 17   58                  1
# 18   19                  0
# 19   18                  0
# 20   21                  0
# 21   26                  0
# 22   40                  1
# 23   45                  1
# 24   50                  1
# 25   54                  1
# 26   23                  0

# %%
df.head()
# Out:
#    age  braught_insurance
# 0   22                  0
# 1   25                  0
# 2   47                  1
# 3   52                  0
# 4   46                  1

# %%
  sns.lmplot(x = "age",y="braught_insurance",data = df)

# %%
vinay = linear_model.LinearRegression()

# %%
vinay. fit(df[["age"]],df["braught_insurance"])
# Out:
# LinearRegression()

# %%
vinay.predict([[21]])
# Out:
# C:\Users\samud\AppData\Roaming\Python\Python312\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([0.07641834])

# %%
vinay.predict([[60]])
# Out:
# C:\Users\samud\AppData\Roaming\Python\Python312\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([1.00009193])

# %%
vinay.coef_
# Out:
# array([0.02368394])

# %%
vinay.intercept_
# Out:
# np.float64(-0.4209443697498305)

# %%
 sns.lmplot(x = "age",y="braught_insurance",data = df)

# %%
import pandas as pd 
import numpy as np  
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from sklearn import linear_model

# %%
df = pd.read_csv(r"C:\Users\samud\Downloads\salary_data.csv")
df
# Out:
#     YearsExperience    Salary
# 0               1.1   39343.0
# 1               1.3   46205.0
# 2               1.5   37731.0
# 3               2.0   43525.0
# 4               2.2   39891.0
# 5               2.9   56642.0
# 6               3.0   60150.0
# 7               3.2   54445.0
# 8               3.2   64445.0
# 9               3.7   57189.0
# 10              3.9   63218.0
# 11              4.0   55794.0
# 12              4.0   56957.0
# 13              4.1   57081.0
# 14              4.5   61111.0
# 15              4.9   67938.0
# 16              5.1   66029.0
# 17              5.3   83088.0
# 18              5.9   81363.0
# 19              6.0   93940.0
# 20              6.8   91738.0
# 21              7.1   98273.0
# 22              7.9  101302.0
# 23              8.2  113812.0
# 24              8.7  109431.0
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# 29             10.5  121872.0

# %%
df.head()
# Out:
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0
# 2              1.5  37731.0
# 3              2.0  43525.0
# 4              2.2  39891.0

# %%
sns.lmplot(x = "YearsExperience",y ="Salary",data =df)

# %%
vinu = linear_model.LinearRegression()

# %%
vinu .fit(df[["YearsExperience"]],df["Salary"])
# Out:
# LinearRegression()

# %%
vinu.predict([[1.0]])
# Out:
# C:\Users\samud\AppData\Roaming\Python\Python312\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([35242.16252012])

# %%
vinu.coef_
# Out:
# array([9449.96232146])

# %%
vinu.intercept_
# Out:
# np.float64(25792.20019866871)

# %%
df = pd.read_csv(r"C:\Users\samud\Downloads\salary_data.csv")
df
# Out:
#     YearsExperience    Salary
# 0               1.1   39343.0
# 1               1.3   46205.0
# 2               1.5   37731.0
# 3               2.0   43525.0
# 4               2.2   39891.0
# 5               2.9   56642.0
# 6               3.0   60150.0
# 7               3.2   54445.0
# 8               3.2   64445.0
# 9               3.7   57189.0
# 10              3.9   63218.0
# 11              4.0   55794.0
# 12              4.0   56957.0
# 13              4.1   57081.0
# 14              4.5   61111.0
# 15              4.9   67938.0
# 16              5.1   66029.0
# 17              5.3   83088.0
# 18              5.9   81363.0
# 19              6.0   93940.0
# 20              6.8   91738.0
# 21              7.1   98273.0
# 22              7.9  101302.0
# 23              8.2  113812.0
# 24              8.7  109431.0
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# 29             10.5  121872.0

# %%
df.head()
# Out:
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0
# 2              1.5  37731.0
# 3              2.0  43525.0
# 4              2.2  39891.0

# %%
sns.lmplot(x = "Salary", y= "YearsExperience", data = df)

# %%
vinu = linear_model.LinearRegression()

# %%
vinu.fit(df[["Salary"]],df[ "YearsExperience"])
# Out:
# LinearRegression()

# %%
# predict the data value

# %%
vinu.predict([[1]])
# Out:
# C:\Users\samud\AppData\Roaming\Python\Python312\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([-2.3830593])

# %%
vinu.coef_
# Out:
# array([0.00010127])

# %%
vinu.intercept_
# Out:
# np.float64(-2.3831605648243537)
